# %% [markdown]
# ![work.jpg](attachment:1a2a11fe-d1bf-47af-8af3-0cf9c7c44577.jpg)

# %% [markdown]
# 1.START
# 2.DISPLAY "items bought"
# 3.CONFIRM number of items bought
# 4.IF payment method is "Cash" then
# 5.   COLLECT Cash
# 6.ELSE IF payment method is "Tranfer" then
# 7. ACCEPT Transfer
# 8.ELSE We do not accept other form of payment
# 9.ISSUE Receipt
# 10.IF Receipt does not correspond with number of items THEN
# 11.    COMPLAIN to store
# 12.    COLLECT new receipt
# 13.    EXIT Store
# 14.
# 15.ELSE IF receipt CorrespondS
# 16.    EXIT Store
# 17.STOP

# %% [markdown]
# ![eeee-Page-2.jpg](attachment:4e7b4d45-4263-4da8-8e20-383ec20f3489.jpg)

# %%
1.START
2.INPUT NAME FOR FIRST PERSON
3.INPUT AGE FOR FIRST PERSON
4.INPUT NAME FOR SECOND PERSON
5.INPUT AGE FOR SECOND PERSON
6. CREATE NEW VARIABLE FOR THE AGE OF THE FIRST PERSON
7.EQUATE VARIABLE FOR SECOND AGE TO VARIABLE FOR FIRST AGE
8.EQUATE
