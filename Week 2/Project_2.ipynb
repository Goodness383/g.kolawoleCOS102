# %%
import numpy as np
def polynomial():
    
    print("Input 1 if you want to solve a quadratic equation")
    print("Input 2 if you want to solve a cubic equation")
    print("Input 3 if you want to solve a quartic equation")
    choice=input("Enter your Choice: ")
    

    
    if choice=='1':
                a=float(input("enter your value for the a coefficient: "))
                b=float(input("enter your value for the b coefficient: "))
                c=float(input("enter your value for the c coefficient: "))
                coeffs=[a,b,c]
                roots=np.roots(coeffs)
                print("Roots are:",roots )
    elif choice=="2":
                a=float(input("enter your value for the a coefficient: "))
                b=float(input("enter your value for the b coefficient: "))
                c=float(input("enter your value for the c coefficient: "))
                d=float(input("enter your value for the d coefficient: "))
                coeffs=[a,b,c,d]
                roots=np.roots(coeffs)
                print("Roots are:",roots )
    elif choice=="3":
                a=float(input("enter your value for the a coefficient: "))
                b=float(input("enter your value for the b coefficient: "))
                c=float(input("enter your value for the c coefficient: "))
                d=float(input("enter your value for the d coefficient: "))
                e=float(input("enter your value for the e coefficient: "))      
                coeffs=[a,b,c,d,e]
                roots=np.roots(coeffs)
                print("Roots are:",roots )
    else:
         print("Wrong input")
polynomial()
# Out:
# Input 1 if you want to solve a quadratic equation
# Input 2 if you want to solve a cubic equation
# Input 3 if you want to solve a quartic equation
# Enter your Choice:  1
# enter your value for the a coefficient:  1
# enter your value for the b coefficient:  3
# enter your value for the c coefficient:  4
# Roots are: [-1.5+1.32287566j -1.5-1.32287566j]
